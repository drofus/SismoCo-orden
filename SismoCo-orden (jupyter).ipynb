# %%
import pandas as pd
import numpy as np
from sys import exit
import csv
import re
import xml.etree.ElementTree as ET
import gzip,io
import json,gzip

# %%
tabla=pd.read_csv("Municipios-Poblados-Colombia-DANE.csv") #DATAFRAME

# %%
def Menu():
    
    print("""******** 
            Bases de datos de Municipios y Departamentos de colombia 
            ********
            Menu:
        
        1) Dataframe "Departamentos". Columnas: nombre, código.
        
        2) Dataframe "Municipios". Columnas: nombre, código, departamento.
        
        3) Dataframe "Poblados". Columnas: nombre, código, municipio.
        
        4) Dataframe "Todo"
        
        5) Salir """)

# %%
def Datos():
    
    Menu()
    
    opc = int(input("seleccione una opcion\n"))
    
    while (opc > 0 and opc < 5):
        
        if opc == 1:
            
            print(tabla[['Nombre-Departamento','Codigo-Departamento']])
            
            opc = int(input("seleccione una opcion\n"))
            
        elif opc == 2:
            
            print(tabla[['Nombre-Municipio','Codigo-Municipio','Nombre-Departamento']])
            
            opc = int(input("seleccione una opcion\n"))
            
        elif opc == 3:
            
            print(tabla[['Nombre-Poblado','Codigo-Poblado','Nombre-Municipio']])
            
            opc = int(input("seleccione una opcion\n"))
            
        elif opc == 4:
            
            print(tabla)
            
            opc = int(input("seleccione una opcion\n"))

# %%
Datos()
# Out:
# ********
#             Bases de datos de Municipios y Departamentos de colombia
#             ********
#             Menu:
#
#         1) Dataframe "Departamentos". Columnas: nombre, código.
#
#         2) Dataframe "Municipios". Columnas: nombre, código, departamento.
#
#         3) Dataframe "Poblados". Columnas: nombre, código, municipio.
#
#         4) Dataframe "Todo"
#
#         5) Salir
# seleccione una opcion
# 1
#      Nombre-Departamento  Codigo-Departamento
# 0              ANTIOQUIA                    5
# 1              ANTIOQUIA                    5
# 2              ANTIOQUIA                    5
# 3              ANTIOQUIA                    5
# 4              ANTIOQUIA                    5
# 5              ANTIOQUIA                    5
# 6              ANTIOQUIA                    5
# 7              ANTIOQUIA                    5
# 8              ANTIOQUIA                    5
# 9              ANTIOQUIA                    5
# 10             ANTIOQUIA                    5
# 11             ANTIOQUIA                    5
# 12             ANTIOQUIA                    5
# 13             ANTIOQUIA                    5
# 14             ANTIOQUIA                    5
# 15             ANTIOQUIA                    5
# 16             ANTIOQUIA                    5
# 17             ANTIOQUIA                    5
# 18             ANTIOQUIA                    5
# 19             ANTIOQUIA                    5
# 20             ANTIOQUIA                    5
# 21             ANTIOQUIA                    5
# 22             ANTIOQUIA                    5
# 23             ANTIOQUIA                    5
# 24             ANTIOQUIA                    5
# 25             ANTIOQUIA                    5
# 26             ANTIOQUIA                    5
# 27             ANTIOQUIA                    5
# 28             ANTIOQUIA                    5
# 29             ANTIOQUIA                    5
# ...                  ...                  ...
# 9175              VAUPÉS                   97
# 9176             VICHADA                   99
# 9177             VICHADA                   99
# 9178             VICHADA                   99
# 9179             VICHADA                   99
# 9180             VICHADA                   99
# 9181             VICHADA                   99
# 9182             VICHADA                   99
# 9183             VICHADA                   99
# 9184             VICHADA                   99
# 9185             VICHADA                   99
# 9186             VICHADA                   99
# 9187             VICHADA                   99
# 9188             VICHADA                   99
# 9189             VICHADA                   99
# 9190             VICHADA                   99
# 9191             VICHADA                   99
# 9192             VICHADA                   99
# 9193             VICHADA                   99
# 9194             VICHADA                   99
# 9195             VICHADA                   99
# 9196             VICHADA                   99
# 9197             VICHADA                   99
# 9198             VICHADA                   99
# 9199             VICHADA                   99
# 9200             VICHADA                   99
# 9201             VICHADA                   99
# 9202             VICHADA                   99
# 9203             VICHADA                   99
# 9204             VICHADA                   99
#
# [9205 rows x 2 columns]
# seleccione una opcion
# 4
#       Codigo-Departamento  Codigo-Municipio  Codigo-Poblado  \
# 0                       5              5001         5001000
# 1                       5              5001         5001001
# 2                       5              5001         5001004
# 3                       5              5001         5001005
# 4                       5              5001         5001009
# 5                       5              5001         5001010
# 6                       5              5001         5001012
# 7                       5              5001         5001013
# 8                       5              5001         5001014
# 9                       5              5001         5001015
# 10                      5              5001         5001017
# 11                      5              5001         5001018
# 12                      5              5001         5001019
# 13                      5              5001         5001020
# 14                      5              5001         5001022
# 15                      5              5001         5001023
# 16                      5              5001         5001024
# 17                      5              5001         5001025
# 18                      5              5001         5001027
# 19                      5              5001         5001029
# 20                      5              5001         5001031
# 21                      5              5001         5001032
# 22                      5              5001         5001033
# 23                      5              5001         5001034
# 24                      5              5001         5001035
# 25                      5              5001         5001036
# 26                      5              5001         5001037
# 27                      5              5001         5001038
# 28                      5              5001         5001039
# 29                      5              5001         5001040
# ...                   ...               ...             ...
# 9175                   97             97889        97889001
# 9176                   99             99001        99001000
# 9177                   99             99001        99001001
# 9178                   99             99001        99001002
# 9179                   99             99524        99524000
# 9180                   99             99524        99524001
# 9181                   99             99524        99524002
# 9182                   99             99524        99524005
# 9183                   99             99524        99524006
# 9184                   99             99524        99524007
# 9185                   99             99524        99524008
# 9186                   99             99624        99624000
# 9187                   99             99624        99624001
# 9188                   99             99773        99773000
# 9189                   99             99773        99773001
# 9190                   99             99773        99773002
# 9191                   99             99773        99773003
# 9192                   99             99773        99773004
# 9193                   99             99773        99773005
# 9194                   99             99773        99773008
# 9195                   99             99773        99773010
# 9196                   99             99773        99773013
# 9197                   99             99773        99773015
# 9198                   99             99773        99773017
# 9199                   99             99773        99773018
# 9200                   99             99773        99773019
# 9201                   99             99773        99773020
# 9202                   99             99773        99773021
# 9203                   99             99773        99773022
# 9204                   99             99773        99773023
#
#      Nombre-Departamento Nombre-Municipio           Nombre-Poblado Tipo
# 0              ANTIOQUIA         MEDELLÍN                 MEDELLÍN   CM
# 1              ANTIOQUIA         MEDELLÍN                 PALMITAS    C
# 2              ANTIOQUIA         MEDELLÍN              SANTA ELENA    C
# 3              ANTIOQUIA         MEDELLÍN            PEDREGAL ALTO  IPM
# 4              ANTIOQUIA         MEDELLÍN                ALTAVISTA    C
# 5              ANTIOQUIA         MEDELLÍN              AGUAS FRÍAS   CP
# 6              ANTIOQUIA         MEDELLÍN                  LA LOMA   CP
# 7              ANTIOQUIA         MEDELLÍN  SAN JOSÉ DEL MANZANILLO   CP
# 8              ANTIOQUIA         MEDELLÍN             BARRO BLANCO   CP
# 9              ANTIOQUIA         MEDELLÍN                 EL CERRO   CP
# 10             ANTIOQUIA         MEDELLÍN                 EL PATIO   CP
# 11             ANTIOQUIA         MEDELLÍN                EL PLACER   CP
# 12             ANTIOQUIA         MEDELLÍN                  EL PLAN   CP
# 13             ANTIOQUIA         MEDELLÍN                EL TESORO   CP
# 14             ANTIOQUIA         MEDELLÍN                 LA ALDEA   CP
# 15             ANTIOQUIA         MEDELLÍN              LA CUCHILLA   CP
# 16             ANTIOQUIA         MEDELLÍN               LA FLORIDA   CP
# 17             ANTIOQUIA         MEDELLÍN                 LA PALMA   CP
# 18             ANTIOQUIA         MEDELLÍN               LAS PLAYAS   CP
# 19             ANTIOQUIA         MEDELLÍN             PIEDRA GORDA   CP
# 20             ANTIOQUIA         MEDELLÍN                POTRERITO   CP
# 21             ANTIOQUIA         MEDELLÍN                TRAVESIAS   CP
# 22             ANTIOQUIA         MEDELLÍN                  URQUITA   CP
# 23             ANTIOQUIA         MEDELLÍN         BARRIOS DE JESÚS   CP
# 24             ANTIOQUIA         MEDELLÍN                 BOQUERÓN   CP
# 25             ANTIOQUIA         MEDELLÍN               CHACALTAYA   CP
# 26             ANTIOQUIA         MEDELLÍN               EL CORAZÓN   CP
# 27             ANTIOQUIA         MEDELLÍN                EL JARDÍN   CP
# 28             ANTIOQUIA         MEDELLÍN               EL LLANO 1   CP
# 29             ANTIOQUIA         MEDELLÍN               EL LLANO 2   CP
# ...                  ...              ...                      ...  ...
# 9175              VAUPÉS         YAVARATÉ                   PAPURÍ   IP
# 9176             VICHADA   PUERTO CARREÑO           PUERTO CARREÑO   CM
# 9177             VICHADA   PUERTO CARREÑO             LA VENTUROSA   IP
# 9178             VICHADA   PUERTO CARREÑO                CASUARITO    C
# 9179             VICHADA     LA PRIMAVERA             LA PRIMAVERA   CM
# 9180             VICHADA     LA PRIMAVERA          NUEVA ANTIOQUIA    C
# 9181             VICHADA     LA PRIMAVERA            SANTA BÁRBARA   IP
# 9182             VICHADA     LA PRIMAVERA                 MARANDÚA  IPM
# 9183             VICHADA     LA PRIMAVERA                 MATIYURE  IPM
# 9184             VICHADA     LA PRIMAVERA  SAN TEODORO (LA PASCUA)  IPM
# 9185             VICHADA     LA PRIMAVERA            SANTA CECILIA  IPM
# 9186             VICHADA    SANTA ROSALÍA            SANTA ROSALÍA   CM
# 9187             VICHADA    SANTA ROSALÍA                GUACACÍAS   IP
# 9188             VICHADA         CUMARIBO                 CUMARIBO   CM
# 9189             VICHADA         CUMARIBO                PALMARITO   IP
# 9190             VICHADA         CUMARIBO                EL VIENTO   IP
# 9191             VICHADA         CUMARIBO               TRES MATAS   IP
# 9192             VICHADA         CUMARIBO                 AMANAVÉN   IP
# 9193             VICHADA         CUMARIBO                  CHUPAVE  CAS
# 9194             VICHADA         CUMARIBO                  GUANAPE  IPM
# 9195             VICHADA         CUMARIBO          PUERTO PRÍNCIPE   IP
# 9196             VICHADA         CUMARIBO            PUERTO NARIÑO  IPM
# 9197             VICHADA         CUMARIBO               SANTA RITA    C
# 9198             VICHADA         CUMARIBO                CHAPARRAL  CAS
# 9199             VICHADA         CUMARIBO                    EL 15  CAS
# 9200             VICHADA         CUMARIBO             EL CAÑAVERAL  CAS
# 9201             VICHADA         CUMARIBO              EL PROGRESO  CAS
# 9202             VICHADA         CUMARIBO               EL TUPARRO   IP
# 9203             VICHADA         CUMARIBO                    LA 14  CAS
# 9204             VICHADA         CUMARIBO                   WERIMA   IP
#
# [9205 rows x 7 columns]
# seleccione una opcion
# 5
